# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-5.16.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\coleg\anaconda3\lib\site-packages (from transformers) (1.30.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\coleg\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\coleg\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\coleg\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.9.3-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<0.24.0,>=0.23.1 (from transformers)
#   Downloading tokenizers-0.23.2-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer in c:\users\coleg\anaconda3\lib\site-packages (from transformers) (0.27.2)
# Collecting safetensors>=0.8.0 (from transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.60 in c:\users\coleg\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\users\coleg\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\coleg\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\coleg\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in c:\users\coleg\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\coleg\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\coleg\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.16.0)
# Requirement already satisfied: colorama in c:\users\coleg\anaconda3\lib\site-packages (from tqdm>=4.60->transformers) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\coleg\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\coleg\anaconda3\lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\coleg\anaconda3\lib\site-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: anyio in c:\users\coleg\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.15.1)
# Requirement already satisfied: certifi in c:\users\coleg\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\coleg\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\coleg\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.19)
# Requirement already satisfied: sniffio in c:\users\coleg\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: h11>=0.16 in c:\users\coleg\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\coleg\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\coleg\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\coleg\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.0)
# Downloading transformers-5.16.1-py3-none-any.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.1 MB 12.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.1 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.1 MB 20.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 18.9 MB/s eta 0:00:00
# Downloading regex-2026.9.3-cp312-cp312-win_amd64.whl (277 kB)
# Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Downloading tokenizers-0.23.2-cp310-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 33.3 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, tokenizers, transformers
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.9.11
#     Uninstalling regex-2024.9.11:
#       Successfully uninstalled regex-2024.9.11
# Successfully installed regex-2026.9.3 safetensors-0.8.0 tokenizers-0.23.2 transformers-5.16.1

# %%
import gradio as gr
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

def generate_caption(image):
    # Now directly using the PIL Image object
    inputs = processor(images=image, return_tensors="pt")
    outputs = model.generate(**inputs)
    caption = processor.decode(outputs[0], skip_special_tokens=True)
    return caption

def caption_image(image):
    """
    Takes a PIL Image input and returns a caption.
    """
    try:
        caption = generate_caption(image)
        return caption
    except Exception as e:
        return f"An error occurred: {str(e)}"

iface = gr.Interface(
    fn=caption_image,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Image Captioning with BLIP",
    description="Upload an image to generate a caption."
)

iface.launch(server_name="127.0.0.1")
# Out:
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  990MB
# pytorch_model.bin: downloading bytes:           |  0.00B
